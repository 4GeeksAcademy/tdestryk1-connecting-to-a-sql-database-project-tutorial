# %% [markdown]
# # SQL Assignment: Setting Up the Database Connection
# In this assignment, you will learn how to connect to a database using `SQLAlchemy` and environment variables. Follow the steps below carefully to set up the connection to your database.
#
# ### Install all libraries
# Let's start by installing all the libraries listed in `requirements.txt`:

# %%
# TODO: Run this cell to install libraries listed in `requirements.txt`
# !pip install -r ../requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: asttokens==2.4.1 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 1)) (2.4.1)
# Requirement already satisfied: branca==0.8.0 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 2)) (0.8.0)
# Requirement already satisfied: comm==0.2.2 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 3)) (0.2.2)
# Requirement already satisfied: contourpy==1.3.0 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: cycler==0.12.1 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: debugpy==1.8.6 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 6)) (1.8.6)
# Requirement already satisfied: decorator==5.1.1 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 7)) (5.1.1)
# Requirement already satisfied: exceptiongroup==1.2.2 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 8)) (1.2.2)
# Requirement already satisfied: executing==2.1.0 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 9)) (2.1.0)
# Requirement already satisfied: fonttools==4.54.1 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 10)) (4.54.1)
# Requirement already satisfied: greenlet==3.1.1 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 11)) (3.1.1)
# Requirement already satisfied: ipykernel==6.29.5 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 12)) (6.29.5)
# Requirement already satisfied: ipython==8.28.0 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 13)) (8.28.0)
# Requirement already satisfied: ipywidgets==8.1.5 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 14)) (8.1.5)
# Requirement already satisfied: jedi==0.19.1 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 15)) (0.19.1)
# Requirement already satisfied: Jinja2==3.1.4 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 16)) (3.1.4)
# Requirement already satisfied: joblib==1.4.2 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 17)) (1.4.2)
# Requirement already satisfied: jupyter-leaflet==0.19.2 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 18)) (0.19.2)
# Requirement already satisfied: jupyter_client==8.6.3 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 19)) (8.6.3)
# Requirement already satisfied: jupyter_core==5.7.2 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 20)) (5.7.2)
# Requirement already satisfied: jupyterlab_widgets==3.0.13 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 21)) (3.0.13)
# Requirement already satisfied: kiwisolver==1.4.7 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 22)) (1.4.7)
# Requirement already satisfied: MarkupSafe==2.1.5 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 23)) (2.1.5)
# Requirement already satisfied: matplotlib-inline==0.1.7 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 24)) (0.1.7)
# Requirement already satisfied: mpmath==1.3.0 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 25)) (1.3.0)
# Requirement already satisfied: nest-asyncio==1.6.0 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 26)) (1.6.0)
# Requirement already satisfied: numpy==2.1.1 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 27)) (2.1.1)
# Requirement already satisfied: packaging==24.1 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 28)) (24.1)
# Requirement already satisfied: pandas==2.2.3 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 29)) (2.2.3)
# Requirement already satisfied: parso==0.8.4 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 30)) (0.8.4)
# Requirement already satisfied: pexpect==4.9.0 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 31)) (4.9.0)
# Requirement already satisfied: pillow==10.4.0 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 32)) (10.4.0)
# Requirement already satisfied: platformdirs==4.3.6 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 33)) (4.3.6)
# Requirement already satisfied: prompt_toolkit==3.0.48 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 34)) (3.0.48)
# Requirement already satisfied: psutil==6.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 35)) (6.0.0)
# Requirement already satisfied: psycopg2==2.9.9 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 36)) (2.9.9)
# Requirement already satisfied: ptyprocess==0.7.0 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 37)) (0.7.0)
# Requirement already satisfied: pure_eval==0.2.3 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 38)) (0.2.3)
# Requirement already satisfied: Pygments==2.18.0 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 39)) (2.18.0)
# Requirement already satisfied: pyparsing==3.1.4 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 40)) (3.1.4)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 41)) (2.9.0.post0)
# Requirement already satisfied: python-dotenv==1.0.1 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 42)) (1.0.1)
# Requirement already satisfied: pytz==2024.2 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 43)) (2024.2)
# Requirement already satisfied: pyzmq==26.2.0 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 44)) (26.2.0)
# Requirement already satisfied: scipy==1.14.1 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 45)) (1.14.1)
# Requirement already satisfied: six==1.16.0 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 46)) (1.16.0)
# Requirement already satisfied: SQLAlchemy==2.0.35 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 47)) (2.0.35)
# Requirement already satisfied: stack-data==0.6.3 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 48)) (0.6.3)
# Requirement already satisfied: threadpoolctl==3.5.0 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 49)) (3.5.0)
# Requirement already satisfied: tornado==6.4.1 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 50)) (6.4.1)
# Requirement already satisfied: traitlets==5.14.3 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 51)) (5.14.3)
# Requirement already satisfied: traittypes==0.2.1 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 52)) (0.2.1)
# Requirement already satisfied: typing_extensions==4.12.2 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 53)) (4.12.2)
# Requirement already satisfied: tzdata==2024.2 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 54)) (2024.2)
# Requirement already satisfied: wcwidth==0.2.13 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 55)) (0.2.13)
# Requirement already satisfied: widgetsnbextension==4.0.13 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 56)) (4.0.13)
# Requirement already satisfied: xyzservices==2024.9.0 in /home/vscode/.local/lib/python3.10/site-packages (from -r ../requirements.txt (line 57)) (2024.9.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Create a `.env` file
# 1. In the root directory of your project, you should see a file named `.env.example`. This file provides a template for setting up your database connection variables.
#
# 2. Duplicate the `.env.example` file and rename the copy to `.env`. You can do this in your terminal or file explorer.
#     - In the terminal, run the following command:
#
#         ```python
#         cp .env.example .env
#         ```
#
# 3. Open the `.env` file and modify the following line:
#
#     ```python
#     DB_NAME = '<your database name>'
#     ```
#
#     Replace `<your database name>` with the name of your custom database. For example:
#
#     ```python
#     DB_NAME = 'my_database'
#     ```
#
# 4. Save the changes to the `.env` file.

# %% [markdown]
# ### Verify Your `.env` File Setup
# 1. Run the following code cell to confirm that the environment variables in your `.env` file are being loaded correctly:

# %%
# TODO: Run this cell to import the necessary libraries and load your variables you set in your .env file
import os
from sqlalchemy import create_engine, inspect
import pandas as pd
from dotenv import load_dotenv

# Load the .env file variables
# The output of this command should be `True`
# If the output is `False`, that means you did not create a valid .env file in the root directory of this project
load_dotenv()
# Out:
# True

# %% [markdown]
# 2. If your `.env` file is set up correctly, the command should return `True`. If it returns `False`, check the following:
#
#     - Ensure the `.env` file is located in the **root directory** of your project.
#
#     - Double-check that you replaced `<your database name>` with your actual database name.
#
#     - Make sure there are no syntax errors in the `.env` file (e.g., no extra spaces or missing values).
#
# 3. You can also validate and inspect your environment variables by running the following code cell:

# %%
# Inspect the environment variables
print(os.getenv('DB_USER'))
print(os.getenv('DB_HOST'))
print(os.getenv('DB_NAME'))
print(os.getenv('DB_PASSWORD'))
# Out:
# gitpod
# localhost
# tdestryk
# postgres

# %% [markdown]
# ### Connecting to the Database
# Now that you have set up your `.env` file and confirmed the environment variables are loaded correctly, it’s time to establish a connection to your database using `SQLAlchemy`'s `create_engine` function.
#
# 1. Run the following code to establish a connection:

# %%
# 1) Connect to the database here using the SQLAlchemy's `create_engine`` function
# A "connection string" is basically a string containing all database credentials together.
connection_string = f"postgresql://{os.getenv('DB_USER')}:{os.getenv('DB_PASSWORD')}@{os.getenv('DB_HOST')}/{os.getenv('DB_NAME')}"
engine = create_engine(connection_string)
engine.connect()
print("Starting the connection...")
# Out:
# Starting the connection...

# %% [markdown]
# 2. **Handling the `... FATAL:  database "<DB_NAME>" does not exist` Error**
#
#     - If the connection attempt throws the following error:
#
#         ```python
#         ... FATAL:  database "<DB_NAME>" does not exist
#         ```
#
#         This means your database hasn't been created yet. To fix this, follow theses steps:
#
#     - Open your **terminal**
#
#     - Run the following command to create your database, making sure to replace `<DB_USER>` and `<DB_NAME>` with the values you set in your `.env` file:
#
#         ```python
#         createdb -h localhost -U <DB_USER> <DB_NAME>
#         ```
#
#         For example, if you set `DB_USER` to `gitpod` and `DB_NAME` to `marisols_database`, the command would be:
#
#         ```python
#         createdb -h localhost -U gitpod marisols_database
#         ```
#
#     - If prompted, enter the password you set in your `.env` file for the `DB_USER`
#
#     - Rerun the code cell above. If successfull, the output will be `Starting the connection...`

# %% [markdown]
# ### Inspecting the Database for Tables
# Now that you've connected to the database, let's check whether any tables currently exist. Since you haven't created any tables yet, the output should be an empty list.
#
# `SQLAlchemy` provides a helpful function called `inspect` to examine the database. In this step, you'll use it to list all existing tables in the database.
#
# Run the following code to inspect the database:

# %%
# We can inspect our database by creating an inspector object
inspector = inspect(engine)

# Get the table names
table_names = inspector.get_table_names()

# Print the table names
print(f"Existing tables in the database: {table_names}")
# Out:
# Existing tables in the database: ['publishers', 'books', 'book_authors', 'authors']

# %% [markdown]
# Since the database is currently empty (you haven’t created any tables yet).

# %% [markdown]
# ### Creating Tables in the Database
# We need to create four tables: `publishers`, `authors`, `books`, and `book_authors`, with foreign key relationships between them. These relationships will help organize the data logically and maintain integrity.
#
# - **Check if a table exists**: To avoid errors from trying to create a table that already exists, we use `CREATE TABLE IF NOT EXISTS`. This ensures that the table is created only if it doesn't already exist in the database.
#
# Run the following code to create the tables:

# %%
from sqlalchemy import text

# Connect to the database
with engine.begin() as connection:
    # Execute the SQL statements to create tables
    connection.execute(text("""
    CREATE TABLE IF NOT EXISTS publishers(
        publisher_id INT NOT NULL,
        name VARCHAR(255) NOT NULL,
        PRIMARY KEY(publisher_id)
    );

    CREATE TABLE IF NOT EXISTS authors(
        author_id INT NOT NULL,
        first_name VARCHAR(100) NOT NULL,
        middle_name VARCHAR(50) NULL,
        last_name VARCHAR(100) NULL,
        PRIMARY KEY(author_id)
    );

    CREATE TABLE IF NOT EXISTS books(
        book_id INT NOT NULL,
        title VARCHAR(255) NOT NULL,
        total_pages INT NULL,
        rating DECIMAL(4, 2) NULL,
        isbn VARCHAR(13) NULL,
        published_date DATE,
        publisher_id INT NULL,
        PRIMARY KEY(book_id),
        CONSTRAINT fk_publisher FOREIGN KEY(publisher_id) REFERENCES publishers(publisher_id)
    );

    CREATE TABLE IF NOT EXISTS book_authors (
        book_id INT NOT NULL,
        author_id INT NOT NULL,
        PRIMARY KEY(book_id, author_id),
        CONSTRAINT fk_book FOREIGN KEY(book_id) REFERENCES books(book_id) ON DELETE CASCADE,
        CONSTRAINT fk_author FOREIGN KEY(author_id) REFERENCES authors(author_id) ON DELETE CASCADE
    );
    """))

# %% [markdown]
# After running the SQL statements, you can re-inspect the database to confirm that the tables were created successfully:

# %%
# Let's inspect out database again to confirm that the tables were created
inspector = inspect(engine)

# Get the table names
table_names = inspector.get_table_names()

# Print the table names
print(f"Existing tables in the database: {table_names}")
# Out:
# Existing tables in the database: ['publishers', 'books', 'book_authors', 'authors']

# %% [markdown]
# ### Inserting Data into the Tables
# Now you will insert sample data into the tables you created earlier: `publishers`, `authors`, `books`, and `book_authors`. This will allow you to work with real data in your database for further queries and analyses.

# %%
# Execute the SQL sentences to insert data into tables
with engine.begin() as connection:
    connection.execute(text("""
    INSERT INTO publishers(publisher_id, name) VALUES (1, 'O Reilly Media');
    INSERT INTO publishers(publisher_id, name) VALUES (2, 'A Book Apart');
    INSERT INTO publishers(publisher_id, name) VALUES (3, 'A K PETERS');
    INSERT INTO publishers(publisher_id, name) VALUES (4, 'Academic Press');
    INSERT INTO publishers(publisher_id, name) VALUES (5, 'Addison Wesley');
    INSERT INTO publishers(publisher_id, name) VALUES (6, 'Albert&Sweigart');
    INSERT INTO publishers(publisher_id, name) VALUES (7, 'Alfred A. Knopf');

    INSERT INTO authors (author_id, first_name, middle_name, last_name) VALUES (1, 'Merritt', null, 'Eric');
    INSERT INTO authors (author_id, first_name, middle_name, last_name) VALUES (2, 'Linda', null, 'Mui');
    INSERT INTO authors (author_id, first_name, middle_name, last_name) VALUES (3, 'Alecos', null, 'Papadatos');
    INSERT INTO authors (author_id, first_name, middle_name, last_name) VALUES (4, 'Anthony', null, 'Molinaro');
    INSERT INTO authors (author_id, first_name, middle_name, last_name) VALUES (5, 'David', null, 'Cronin');
    INSERT INTO authors (author_id, first_name, middle_name, last_name) VALUES (6, 'Richard', null, 'Blum');
    INSERT INTO authors (author_id, first_name, middle_name, last_name) VALUES (7, 'Yuval', 'Noah', 'Harari');
    INSERT INTO authors (author_id, first_name, middle_name, last_name) VALUES (8, 'Paul', null, 'Albitz');

    INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (1, 'Lean Software Development: An Agile Toolkit', 240, 4.17, '9780320000000', '2003-05-18', 5);
    INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (2, 'Facing the Intelligence Explosion', 91, 3.87, null, '2013-02-01', 7);
    INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (3, 'Scala in Action', 419, 3.74, '9781940000000', '2013-04-10', 1);
    INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (4, 'Patterns of Software: Tales from the Software Community', 256, 3.84, '9780200000000', '1996-08-15', 1);
    INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (5, 'Anatomy Of LISP', 446, 4.43, '9780070000000', '1978-01-01', 3);
    INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (6, 'Computing machinery and intelligence', 24, 4.17, null, '2009-03-22', 4);
    INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (7, 'XML: Visual QuickStart Guide', 269, 3.66, '9780320000000', '2009-01-01', 5);
    INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (8, 'SQL Cookbook', 595, 3.95, '9780600000000', '2005-12-01', 7);
    INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (9, 'The Apollo Guidance Computer: Architecture And Operation (Springer Praxis Books / Space Exploration)', 439, 4.29, '9781440000000', '2010-07-01', 6);
    INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (10, 'Minds and Computers: An Introduction to the Philosophy of Artificial Intelligence', 222, 3.54, '9780750000000', '2007-02-13', 7);

    INSERT INTO book_authors (book_id, author_id) VALUES (1, 1);
    INSERT INTO book_authors (book_id, author_id) VALUES (2, 8);
    INSERT INTO book_authors (book_id, author_id) VALUES (3, 7);
    INSERT INTO book_authors (book_id, author_id) VALUES (4, 6);
    INSERT INTO book_authors (book_id, author_id) VALUES (5, 5);
    INSERT INTO book_authors (book_id, author_id) VALUES (6, 4);
    INSERT INTO book_authors (book_id, author_id) VALUES (7, 3);
    INSERT INTO book_authors (book_id, author_id) VALUES (8, 2);
    INSERT INTO book_authors (book_id, author_id) VALUES (9, 4);
    INSERT INTO book_authors (book_id, author_id) VALUES (10, 1);
    """))
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File ~/.local/lib/python3.10/site-packages/sqlalchemy/engine/default.py:941, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     940 def do_execute(self, cursor, statement, parameters, context=None):
# --> 941     cursor.execute(statement, parameters)
#
# UniqueViolation: duplicate key value violates unique constraint "publishers_pkey"
# DETAIL:  Key (publisher_id)=(1) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Execute the SQL sentences to insert data into tables
#       2 with engine.begin() as connection:
# ----> 3     connection.execute(text("""
#       4     INSERT INTO publishers(publisher_id, name) VALUES (1, 'O Reilly Media');
#       5     INSERT INTO publishers(publisher_id, name) VALUES (2, 'A Book Apart');
#       6     INSERT INTO publishers(publisher_id, name) VALUES (3, 'A K PETERS');
#       7     INSERT INTO publishers(publisher_id, name) VALUES (4, 'Academic Press');
#       8     INSERT INTO publishers(publisher_id, name) VALUES (5, 'Addison Wesley');
#       9     INSERT INTO publishers(publisher_id, name) VALUES (6, 'Albert&Sweigart');
#      10     INSERT INTO publishers(publisher_id, name) VALUES (7, 'Alfred A. Knopf');
#      11
#      12     INSERT INTO authors (author_id, first_name, middle_name, last_name) VALUES (1, 'Merritt', null, 'Eric');
#      13     INSERT INTO authors (author_id, first_name, middle_name, last_name) VALUES (2, 'Linda', null, 'Mui');
#      14     INSERT INTO authors (author_id, first_name, middle_name, last_name) VALUES (3, 'Alecos', null, 'Papadatos');
#      15     INSERT INTO authors (author_id, first_name, middle_name, last_name) VALUES (4, 'Anthony', null, 'Molinaro');
#      16     INSERT INTO authors (author_id, first_name, middle_name, last_name) VALUES (5, 'David', null, 'Cronin');
#      17     INSERT INTO authors (author_id, first_name, middle_name, last_name) VALUES (6, 'Richard', null, 'Blum');
#      18     INSERT INTO authors (author_id, first_name, middle_name, last_name) VALUES (7, 'Yuval', 'Noah', 'Harari');
#      19     INSERT INTO authors (author_id, first_name, middle_name, last_name) VALUES (8, 'Paul', null, 'Albitz');
#      20
#      21     INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (1, 'Lean Software Development: An Agile Toolkit', 240, 4.17, '9780320000000', '2003-05-18', 5);
#      22     INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (2, 'Facing the Intelligence Explosion', 91, 3.87, null, '2013-02-01', 7);
#      23     INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (3, 'Scala in Action', 419, 3.74, '9781940000000', '2013-04-10', 1);
#      24     INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (4, 'Patterns of Software: Tales from the Software Community', 256, 3.84, '9780200000000', '1996-08-15', 1);
#      25     INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (5, 'Anatomy Of LISP', 446, 4.43, '9780070000000', '1978-01-01', 3);
#      26     INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (6, 'Computing machinery and intelligence', 24, 4.17, null, '2009-03-22', 4);
#      27     INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (7, 'XML: Visual QuickStart Guide', 269, 3.66, '9780320000000', '2009-01-01', 5);
#      28     INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (8, 'SQL Cookbook', 595, 3.95, '9780600000000', '2005-12-01', 7);
#      29     INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (9, 'The Apollo Guidance Computer: Architecture And Operation (Springer Praxis Books / Space Exploration)', 439, 4.29, '9781440000000', '2010-07-01', 6);
#      30     INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (10, 'Minds and Computers: An Introduction to the Philosophy of Artificial Intelligence', 222, 3.54, '9780750000000', '2007-02-13', 7);
#      31
#      32     INSERT INTO book_authors (book_id, author_id) VALUES (1, 1);
#      33     INSERT INTO book_authors (book_id, author_id) VALUES (2, 8);
#      34     INSERT INTO book_authors (book_id, author_id) VALUES (3, 7);
#      35     INSERT INTO book_authors (book_id, author_id) VALUES (4, 6);
#      36     INSERT INTO book_authors (book_id, author_id) VALUES (5, 5);
#      37     INSERT INTO book_authors (book_id, author_id) VALUES (6, 4);
#      38     INSERT INTO book_authors (book_id, author_id) VALUES (7, 3);
#      39     INSERT INTO book_authors (book_id, author_id) VALUES (8, 2);
#      40     INSERT INTO book_authors (book_id, author_id) VALUES (9, 4);
#      41     INSERT INTO book_authors (book_id, author_id) VALUES (10, 1);
#      42     """))
#
# File ~/.local/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1418, in Connection.execute(self, statement, parameters, execution_options)
#    1416     raise exc.ObjectNotExecutableError(statement) from err
#    1417 else:
# -> 1418     return meth(
#    1419         self,
#    1420         distilled_parameters,
#    1421         execution_options or NO_OPTIONS,
#    1422     )
#
# File ~/.local/lib/python3.10/site-packages/sqlalchemy/sql/elements.py:515, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     513     if TYPE_CHECKING:
#     514         assert isinstance(self, Executable)
# --> 515     return connection._execute_clauseelement(
#     516         self, distilled_params, execution_options
#     517     )
#     518 else:
#     519     raise exc.ObjectNotExecutableError(self)
#
# File ~/.local/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1640, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1628 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1629     "compiled_cache", self.engine._compiled_cache
#    1630 )
#    1632 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1633     dialect=dialect,
#    1634     compiled_cache=compiled_cache,
#    (...)
#    1638     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1639 )
# -> 1640 ret = self._execute_context(
#    1641     dialect,
#    1642     dialect.execution_ctx_cls._init_compiled,
#    1643     compiled_sql,
#    1644     distilled_parameters,
#    1645     execution_options,
#    1646     compiled_sql,
#    1647     distilled_parameters,
#    1648     elem,
#    1649     extracted_params,
#    1650     cache_hit=cache_hit,
#    1651 )
#    1652 if has_events:
#    1653     self.dispatch.after_execute(
#    1654         self,
#    1655         elem,
#    (...)
#    1659         ret,
#    1660     )
#
# File ~/.local/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File ~/.local/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File ~/.local/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2355, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2353 elif should_wrap:
#    2354     assert sqlalchemy_exception is not None
# -> 2355     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2356 else:
#    2357     assert exc_info[1] is not None
#
# File ~/.local/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1965                 break
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#    1972     self.dispatch.after_cursor_execute(
#    1973         self,
#    1974         cursor,
#    (...)
#    1978         context.executemany,
#    1979     )
#
# File ~/.local/lib/python3.10/site-packages/sqlalchemy/engine/default.py:941, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     940 def do_execute(self, cursor, statement, parameters, context=None):
# --> 941     cursor.execute(statement, parameters)
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "publishers_pkey"
# DETAIL:  Key (publisher_id)=(1) already exists.
#
# [SQL:
#     INSERT INTO publishers(publisher_id, name) VALUES (1, 'O Reilly Media');
#     INSERT INTO publishers(publisher_id, name) VALUES (2, 'A Book Apart');
#     INSERT INTO publishers(publisher_id, name) VALUES (3, 'A K PETERS');
#     INSERT INTO publishers(publisher_id, name) VALUES (4, 'Academic Press');
#     INSERT INTO publishers(publisher_id, name) VALUES (5, 'Addison Wesley');
#     INSERT INTO publishers(publisher_id, name) VALUES (6, 'Albert&Sweigart');
#     INSERT INTO publishers(publisher_id, name) VALUES (7, 'Alfred A. Knopf');
#
#     INSERT INTO authors (author_id, first_name, middle_name, last_name) VALUES (1, 'Merritt', null, 'Eric');
#     INSERT INTO authors (author_id, first_name, middle_name, last_name) VALUES (2, 'Linda', null, 'Mui');
#     INSERT INTO authors (author_id, first_name, middle_name, last_name) VALUES (3, 'Alecos', null, 'Papadatos');
#     INSERT INTO authors (author_id, first_name, middle_name, last_name) VALUES (4, 'Anthony', null, 'Molinaro');
#     INSERT INTO authors (author_id, first_name, middle_name, last_name) VALUES (5, 'David', null, 'Cronin');
#     INSERT INTO authors (author_id, first_name, middle_name, last_name) VALUES (6, 'Richard', null, 'Blum');
#     INSERT INTO authors (author_id, first_name, middle_name, last_name) VALUES (7, 'Yuval', 'Noah', 'Harari');
#     INSERT INTO authors (author_id, first_name, middle_name, last_name) VALUES (8, 'Paul', null, 'Albitz');
#
#     INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (1, 'Lean Software Development: An Agile Toolkit', 240, 4.17, '9780320000000', '2003-05-18', 5);
#     INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (2, 'Facing the Intelligence Explosion', 91, 3.87, null, '2013-02-01', 7);
#     INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (3, 'Scala in Action', 419, 3.74, '9781940000000', '2013-04-10', 1);
#     INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (4, 'Patterns of Software: Tales from the Software Community', 256, 3.84, '9780200000000', '1996-08-15', 1);
#     INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (5, 'Anatomy Of LISP', 446, 4.43, '9780070000000', '1978-01-01', 3);
#     INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (6, 'Computing machinery and intelligence', 24, 4.17, null, '2009-03-22', 4);
#     INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (7, 'XML: Visual QuickStart Guide', 269, 3.66, '9780320000000', '2009-01-01', 5);
#     INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (8, 'SQL Cookbook', 595, 3.95, '9780600000000', '2005-12-01', 7);
#     INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (9, 'The Apollo Guidance Computer: Architecture And Operation (Springer Praxis Books / Space Exploration)', 439, 4.29, '9781440000000', '2010-07-01', 6);
#     INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (10, 'Minds and Computers: An Introduction to the Philosophy of Artificial Intelligence', 222, 3.54, '9780750000000', '2007-02-13', 7);
#
#     INSERT INTO book_authors (book_id, author_id) VALUES (1, 1);
#     INSERT INTO book_authors (book_id, author_id) VALUES (2, 8);
#     INSERT INTO book_authors (book_id, author_id) VALUES (3, 7);
#     INSERT INTO book_authors (book_id, author_id) VALUES (4, 6);
#     INSERT INTO book_authors (book_id, author_id) VALUES (5, 5);
#     INSERT INTO book_authors (book_id, author_id) VALUES (6, 4);
#     INSERT INTO book_authors (book_id, author_id) VALUES (7, 3);
#     INSERT INTO book_authors (book_id, author_id) VALUES (8, 2);
#     INSERT INTO book_authors (book_id, author_id) VALUES (9, 4);
#     INSERT INTO book_authors (book_id, author_id) VALUES (10, 1);
#     ]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %% [markdown]
# ### Load SQL Tables into Pandas DataFrames
# We will use the `pandas` library to read the data from the SQL tables we created and inserted data into in the previous step. The `pd.read_sql` function allows us to execute SQL queries and return the results as pandas DataFrames.
#
# This is useful for analyzing and manipulating the data programmatically. Below are the commands to load each table into its respective DataFrame:

# %%
# Use pandas to print one of the tables as dataframe using read_sql function
# Here we are reading the publishers table as a pandas dataframe
publishers_df = pd.read_sql("SELECT * FROM publishers;", engine)
publishers_df
# Out:
#    publisher_id             name
# 0             1   O Reilly Media
# 1             2     A Book Apart
# 2             3       A K PETERS
# 3             4   Academic Press
# 4             5   Addison Wesley
# 5             6  Albert&Sweigart
# 6             7  Alfred A. Knopf

# %%
# authors table
authors_df = pd.read_sql("SELECT * FROM authors;", engine)
authors_df
# Out:
#    author_id first_name middle_name  last_name
# 0          1    Merritt        None       Eric
# 1          2      Linda        None        Mui
# 2          3     Alecos        None  Papadatos
# 3          4    Anthony        None   Molinaro
# 4          5      David        None     Cronin
# 5          6    Richard        None       Blum
# 6          7      Yuval        Noah     Harari
# 7          8       Paul        None     Albitz

# %%
# books table
books_df = pd.read_sql("SELECT * FROM books;", engine)
books_df
# Out:
#    book_id                                              title  total_pages  \
# 0        1        Lean Software Development: An Agile Toolkit          240
# 1        2                  Facing the Intelligence Explosion           91
# 2        3                                    Scala in Action          419
# 3        4  Patterns of Software: Tales from the Software ...          256
# 4        5                                    Anatomy Of LISP          446
# 5        6               Computing machinery and intelligence           24
# 6        7                       XML: Visual QuickStart Guide          269
# 7        8                                       SQL Cookbook          595
# 8        9  The Apollo Guidance Computer: Architecture And...          439
# 9       10  Minds and Computers: An Introduction to the Ph...          222
#
#    rating           isbn published_date  publisher_id
# 0    4.17  9780320000000     2003-05-18             5
# 1    3.87           None     2013-02-01             7
# 2    3.74  9781940000000     2013-04-10             1
# 3    3.84  9780200000000     1996-08-15             1
# 4    4.43  9780070000000     1978-01-01             3
# 5    4.17           None     2009-03-22             4
# 6    3.66  9780320000000     2009-01-01             5
# 7    3.95  9780600000000     2005-12-01             7
# 8    4.29  9781440000000     2010-07-01             6
# 9    3.54  9780750000000     2007-02-13             7

# %%
# book_authors table
book_authors_df = pd.read_sql("SELECT * FROM book_authors;", engine)
book_authors_df
# Out:
#    book_id  author_id
# 0        1          1
# 1        2          8
# 2        3          7
# 3        4          6
# 4        5          5
# 5        6          4
# 6        7          3
# 7        8          2
# 8        9          4
# 9       10          1

# %% [markdown]
# ## SQL Data Exploration and Analysis
# In this section, you will complete 15 exercises that require you to write SQL queries to extract insights from the `publishers`, `authors`, `books`, and `book_authors` tables.
#
# Read each prompt carefully, then write and execute the appropriate SQL query using the provided SQLAlchemy `engine`. Aim to complete all exercises to enhance your SQL skills and deepen your understanding of data manipulation.

# %%
# 1. Write a SQL query to select all columns and rows from the `books` table. 
# (Hint: Use `*`)
all_books = pd.read_sql("SELECT * FROM books", engine)
all_books
# Out:
#    book_id                                              title  total_pages  \
# 0        1        Lean Software Development: An Agile Toolkit          240
# 1        2                  Facing the Intelligence Explosion           91
# 2        3                                    Scala in Action          419
# 3        4  Patterns of Software: Tales from the Software ...          256
# 4        5                                    Anatomy Of LISP          446
# 5        6               Computing machinery and intelligence           24
# 6        7                       XML: Visual QuickStart Guide          269
# 7        8                                       SQL Cookbook          595
# 8        9  The Apollo Guidance Computer: Architecture And...          439
# 9       10  Minds and Computers: An Introduction to the Ph...          222
#
#    rating           isbn published_date  publisher_id
# 0    4.17  9780320000000     2003-05-18             5
# 1    3.87           None     2013-02-01             7
# 2    3.74  9781940000000     2013-04-10             1
# 3    3.84  9780200000000     1996-08-15             1
# 4    4.43  9780070000000     1978-01-01             3
# 5    4.17           None     2009-03-22             4
# 6    3.66  9780320000000     2009-01-01             5
# 7    3.95  9780600000000     2005-12-01             7
# 8    4.29  9781440000000     2010-07-01             6
# 9    3.54  9780750000000     2007-02-13             7

# %%
# 2. Write a SQL query to select the first 3 rows from the `books` table. 
# (Hint: Use `LIMIT n` where n is the number of rows)
top_three_rows = pd.read_sql("SELECT * FROM books LIMIT 3", engine)
top_three_rows
# Out:
#    book_id                                        title  total_pages  rating  \
# 0        1  Lean Software Development: An Agile Toolkit          240    4.17
# 1        2            Facing the Intelligence Explosion           91    3.87
# 2        3                              Scala in Action          419    3.74
#
#             isbn published_date  publisher_id
# 0  9780320000000     2003-05-18             5
# 1           None     2013-02-01             7
# 2  9781940000000     2013-04-10             1

# %%
# 3. Write a SQL query to select only the `first_name` column of the `authors` table`.
authors_first_names = pd.read_sql("SELECT first_name FROM authors", engine)
authors_first_names
# Out:
#   first_name
# 0    Merritt
# 1      Linda
# 2     Alecos
# 3    Anthony
# 4      David
# 5    Richard
# 6      Yuval
# 7       Paul

# %%
# 4. Write a SQL query to to select only the `title` column of the `books` table`.
book_titles = pd.read_sql("SELECT title FROM books", engine)
book_titles
# Out:
#                                                title
# 0        Lean Software Development: An Agile Toolkit
# 1                  Facing the Intelligence Explosion
# 2                                    Scala in Action
# 3  Patterns of Software: Tales from the Software ...
# 4                                    Anatomy Of LISP
# 5               Computing machinery and intelligence
# 6                       XML: Visual QuickStart Guide
# 7                                       SQL Cookbook
# 8  The Apollo Guidance Computer: Architecture And...
# 9  Minds and Computers: An Introduction to the Ph...

# %%
# 5. Write a SQL query to select only the `name` column of the `publishers` table`.
publishers = pd.read_sql("SELECT name FROM publishers", engine)
publishers
# Out:
#               name
# 0   O Reilly Media
# 1     A Book Apart
# 2       A K PETERS
# 3   Academic Press
# 4   Addison Wesley
# 5  Albert&Sweigart
# 6  Alfred A. Knopf

# %%
# 6. Write a SQL query to select the `title` and `published_date` columns of the `books` table`.
book_dates = pd.read_sql("SELECT title, published_date FROM books", engine)
book_dates
# Out:
#                                                title published_date
# 0        Lean Software Development: An Agile Toolkit     2003-05-18
# 1                  Facing the Intelligence Explosion     2013-02-01
# 2                                    Scala in Action     2013-04-10
# 3  Patterns of Software: Tales from the Software ...     1996-08-15
# 4                                    Anatomy Of LISP     1978-01-01
# 5               Computing machinery and intelligence     2009-03-22
# 6                       XML: Visual QuickStart Guide     2009-01-01
# 7                                       SQL Cookbook     2005-12-01
# 8  The Apollo Guidance Computer: Architecture And...     2010-07-01
# 9  Minds and Computers: An Introduction to the Ph...     2007-02-13

# %%
# 7. Write a SQL query to count the number of rows listed in the `authors` table. 
# (Hint: Use the `COUNT()` command)
row_count = pd.read_sql("SELECT COUNT(*) FROM authors", engine)
row_count
# Out:
#    count
# 0      8

# %%
# 8. Write a SQL query to find the sum of `total_pages` using the `books` table. 
# (Hint: Use the `SUM()` command)
sum_total_pages = pd.read_sql("SELECT SUM(total_pages) FROM books", engine)
sum_total_pages
# Out:
#     sum
# 0  3001

# %%
# 9. Write a SQL query to find the average book `rating` using the `books` table. 
# (Hint: Use the `AVG()` command)
avg_rating = pd.read_sql("SELECT AVG(rating) FROM books", engine)
avg_rating
# Out:
#      avg
# 0  3.966

# %%
# 10. Write a SQL query to find the minimum book `rating` using the `books` table. 
# (Hint: Use the `MIN()` command)
min_rating = pd.read_sql("SELECT MIN(rating) FROM books", engine)
min_rating
# Out:
#     min
# 0  3.54

# %%
# 11. Write a SQL query to find the maximum book `rating` using the `books` table. 
# (Hint: Use the `MAX()` command)
max_rating = pd.read_sql("SELECT MAX(rating) FROM books", engine)
max_rating
# Out:
#     max
# 0  4.43

# %%
# 12. Write a SQL query to list the rows in the `books` table where `isbn` is not None. 
# (Hint: Use the `WHERE()` command)
non_null_isbn_rows = pd.read_sql("SELECT * FROM books WHERE(isbn) IS NOT NULL", engine)
non_null_isbn_rows
# Out:
#    book_id                                              title  total_pages  \
# 0        1        Lean Software Development: An Agile Toolkit          240
# 1        3                                    Scala in Action          419
# 2        4  Patterns of Software: Tales from the Software ...          256
# 3        5                                    Anatomy Of LISP          446
# 4        7                       XML: Visual QuickStart Guide          269
# 5        8                                       SQL Cookbook          595
# 6        9  The Apollo Guidance Computer: Architecture And...          439
# 7       10  Minds and Computers: An Introduction to the Ph...          222
#
#    rating           isbn published_date  publisher_id
# 0    4.17  9780320000000     2003-05-18             5
# 1    3.74  9781940000000     2013-04-10             1
# 2    3.84  9780200000000     1996-08-15             1
# 3    4.43  9780070000000     1978-01-01             3
# 4    3.66  9780320000000     2009-01-01             5
# 5    3.95  9780600000000     2005-12-01             7
# 6    4.29  9781440000000     2010-07-01             6
# 7    3.54  9780750000000     2007-02-13             7

# %%
# 13. Write a SQL query to list the rows in the `books` table where `total_pages` is greater than 400. 
# (Hint: Use the `WHERE()` command)
large_books = pd.read_sql("SELECT * FROM books WHERE(total_pages) > 400 ", engine)
large_books
# Out:
#    book_id                                              title  total_pages  \
# 0        3                                    Scala in Action          419
# 1        5                                    Anatomy Of LISP          446
# 2        8                                       SQL Cookbook          595
# 3        9  The Apollo Guidance Computer: Architecture And...          439
#
#    rating           isbn published_date  publisher_id
# 0    3.74  9781940000000     2013-04-10             1
# 1    4.43  9780070000000     1978-01-01             3
# 2    3.95  9780600000000     2005-12-01             7
# 3    4.29  9781440000000     2010-07-01             6

# %%
# 14. Write a SQL query to list the rows in the `books` table where `published_date` is before 2000-01-01. 
# (Hint: Use the `WHERE()` command)
old_books = pd.read_sql("SELECT * FROM books WHERE(published_date) < '2000-01-01'", engine)
old_books
# Out:
#    book_id                                              title  total_pages  \
# 0        4  Patterns of Software: Tales from the Software ...          256
# 1        5                                    Anatomy Of LISP          446
#
#    rating           isbn published_date  publisher_id
# 0    3.84  9780200000000     1996-08-15             1
# 1    4.43  9780070000000     1978-01-01             3

# %%
tk = pd.read_sql("SELECT * FROM authors", engine)
tk
# Out:
#    author_id first_name middle_name  last_name
# 0          1    Merritt        None       Eric
# 1          2      Linda        None        Mui
# 2          3     Alecos        None  Papadatos
# 3          4    Anthony        None   Molinaro
# 4          5      David        None     Cronin
# 5          6    Richard        None       Blum
# 6          7      Yuval        Noah     Harari
# 7          8       Paul        None     Albitz

# %%
# 15. Write a SQL query to list the book titles along with the first name of the author. 
# (Hint: Several JOINs may be needed)
book_info = pd.read_sql("SELECT books.title, authors.first_name FROM books JOIN book_authors ON books.book_id = book_authors.book_id JOIN authors ON book_authors.author_id = authors.author_id;", engine)
book_info
# Out:
#                                                title first_name
# 0        Lean Software Development: An Agile Toolkit    Merritt
# 1                  Facing the Intelligence Explosion       Paul
# 2                                    Scala in Action      Yuval
# 3  Patterns of Software: Tales from the Software ...    Richard
# 4                                    Anatomy Of LISP      David
# 5               Computing machinery and intelligence    Anthony
# 6                       XML: Visual QuickStart Guide     Alecos
# 7                                       SQL Cookbook      Linda
# 8  The Apollo Guidance Computer: Architecture And...    Anthony
# 9  Minds and Computers: An Introduction to the Ph...    Merritt

# %% [markdown]
# ## How to clear the database

# %%
# Let's clear our database by dropping all our tables
with engine.begin() as connection:
    connection.execute(text("""
        DROP TABLE book_authors;

        DROP TABLE books;

        DROP TABLE authors;

        DROP TABLE publishers;
        """))

# %%
# Let's inspect out database again to confirm that the tables were deleted
inspector = inspect(engine)

# Get the table names
table_names = inspector.get_table_names()

# Print the table names
print(f"Existing tables in the database: {table_names}")
# Out:
# Existing tables in the database: []
